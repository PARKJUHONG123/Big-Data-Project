# %%
import pandas as pd
import folium

# %%
star=pd.read_csv("C:\\Users\\DAEWOONG\\대웅\\Jupyter 연습\\starxy.csv",encoding='cp949')

# %%
star.head()
# Out:
#        NAME                     ADDRESS          x           y
# 0  계명대동산병원   대구광역시 달서구 달구벌대로 1035 (신당동)  35.853887  128.480130
# 1    대구죽전역           대구광역시 달서구 와룡로 169   35.848733  128.536391
# 2   대구월곡DT      대구광역시 달서구 월곡로 225 (상인동)  35.814858  128.541026
# 3     대구광장   대구광역시 달서구 달구벌대로 1710 (두류동)  35.855724  128.552816
# 4    대구월촌역      대구광역시 달서구 월배로 315 (송현동)  35.824018  128.545200

# %%
m=folium.Map(location=[35.8691072,128.5787031],zoom_start=12)

# %%
for i in range(len(star)):
    folium.Marker([star.loc[i,'x'],star.loc[i,'y']],).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
