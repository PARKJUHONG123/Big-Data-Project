# %%
import pandas as pd
import folium

# %%
subway = pd.read_csv("C:\\Users\\DAEWOONG\\Downloads\\전국도시철도역사정보표준데이터.csv")

# %%
sub=subway[['역사명','노선명','역위도','역경도']]

# %%
sub.head()
# Out:
#   역사명        노선명        역위도         역경도
# 0  계양  인천지하철 1호선  37.571539  126.736319
# 1  귤현  인천지하철 1호선  37.566362  126.742498
# 2  박촌  인천지하철 1호선  37.553525  126.744946
# 3  임학  인천지하철 1호선  37.545058  126.738642
# 4  계산  인천지하철 1호선  37.543243  126.728436

# %%
sub=sub[sub['노선명'].isin(['대구 도시철도 1호선','대구 도시철도 2호선','대구 도시철도 3호선'])]

# %%
sub.to_csv("subway.csv",index=False,encoding='ms949')

# %%
S=pd.read_csv("C:\\Users\\DAEWOONG\\대웅\\Jupyter 연습\\subway.csv",encoding='cp949')

# %%
m=folium.Map(location=[35.8691072,128.5787031],zoom_start=12)

# %%
for i in range(len(S)):
    folium.Marker([S.loc[i,'역위도'],S.loc[i,'역경도']],).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df = pd.DataFrame(columns={'a','b','c'})

# %%
df
# Out:
# Empty DataFrame
# Columns: [b, a, c]
# Index: []
